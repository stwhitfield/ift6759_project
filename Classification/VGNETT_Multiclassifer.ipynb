# %%
import os
from google.colab import drive
drive.mount('/content/drive')

#!ls "/content/drive/My Drive/processed_images"
# Out:
# Mounted at /content/drive

# %%
import torch
import numpy as np
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import Dataset, random_split
from PIL import Image
import os
import pandas as pd

transform = transforms.Compose([
    transforms.RandomRotation(30),      # rotate +/- 30 degrees
    transforms.RandomHorizontalFlip(),  # rHorizontally flip the given image randomly with a given probability (default p=0.5)
    #transforms.RandomVerticalFlip() #Vertically flip the given image randomly with a given probability (default p=0.5), not recommended for medical images
    transforms.Resize((224, 224)),       #  be sure to pass in a list or a tuple
    transforms.CenterCrop(224),         # crop longest side to 224 pixels at center
    transforms.RandomAdjustSharpness(1.5, p=0.5), #
    transforms.RandomAdjustSharpness(0.5, p=0.5),
    transforms.RandomAutocontrast(p=0.5),
    transforms.RandomEqualize(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                          [0.229, 0.224, 0.225])
])

class CovidSeverityDataset(Dataset):
    def __init__(self, root_dir, transform = transform, split_lengths = [0.7, 0.1, 0.2], split_seed = 42, batch_size = 10, shuffle = True, num_workers = [2,0,0]):
      self.root_dir = root_dir
      self.csv_path = self.root_dir + "data_processing/combined_cxr_metadata.csv"
      self.data_path = self.root_dir 
      self.transform = transform
      self.split_lengths = split_lengths
      self.split_seed = split_seed
      self.batch_size = batch_size
      self.shuffle = shuffle
      self.num_workers = num_workers
      self.dataframe = pd.read_csv(self.csv_path, index_col=0)
  
    def __len__(self):
      return len(self.dataframe)

    def __getitem__(self, index):
      img_path = os.path.join(self.data_path, self.dataframe.iloc[index, 0])
      image = Image.open(img_path)
      y_label = torch.round(torch.tensor(self.dataframe.iloc[index, 1]))
      if self.transform:
        image = self.transform(image)
      else:
        convert_tensor = transforms.PILToTensor()
        image = convert_tensor(image)
      return (image.float(), y_label.to(torch.int64))
  
    def get_subsets(self):
      subsets = random_split(self, self.split_lengths, generator=torch.Generator().manual_seed(self.split_seed))
      train = torch.utils.data.DataLoader(dataset=subsets[0], batch_size=self.batch_size, shuffle=self.shuffle, num_workers=self.num_workers[0])
      val = torch.utils.data.DataLoader(dataset=subsets[1], batch_size=self.batch_size, shuffle=self.shuffle, num_workers=self.num_workers[1])
      test = torch.utils.data.DataLoader(dataset=subsets[2], batch_size=self.batch_size, shuffle=self.shuffle, num_workers=self.num_workers[2])
      return train, val, test


# How to use this class?
# root_dir = "/content/drive/MyDrive/Mila/Winter_2023/ift6759_project/"
# dataset = CovidSeverityDataset(root_dir, transform = False)
# train, val, test = dataset.get_subsets()


#!ls "/content/drive/My Drive/processed_images"

# %%
root_dir = "/content/drive/My Drive/processed_images/"
dataset = CovidSeverityDataset(root_dir, transform = False)
train, val, test = dataset.get_subsets()

# %% [markdown]
# # Evaluating VGNETT out of box

# %%
print(len(test))
# evaluation dataset : 447/1440 -> 0.31
# Out:
# 144

# %%
import torchvision.models as models
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()

# %%
from torchvision import models
vgg16 = models.vgg16_bn(pretrained=True)
print(vgg16.classifier[6].out_features) # 1000 

for param in vgg16.features.parameters():
    param.require_grad = False

# Newly created modules have require_grad=True by default
num_features = vgg16.classifier[6].in_features
print(num_features)
features = list(vgg16.classifier.children())[:-1] # Remove last layer
features.extend([nn.Linear(num_features, 7)]) # Add our layer with 4 outputs
vgg16.classifier = nn.Sequential(*features) # Replace the model classifier
print(vgg16)
# Out:
# 1000
# 4096
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=7, bias=True)
#   )
# )

# %%
def eval_model(vgg, criterion):
    since = time.time()
    avg_loss = 0
    avg_acc = 0
    loss_test = 0
    acc_test = 0
    
    test_batches = len(test)
    print("Evaluating model")
    print('-' * 10)
    
    for i, data in enumerate(test):
        #print(i)
        if i % 100 == 0:
            print("\rTest batch {}/{}".format(i, test_batches), end='', flush=True)

        vgg.train(False)
        vgg.eval()
        inputs, labels = data
        #print(inputs)
        labels = labels.type(torch.LongTensor)
        #if use_gpu:
        inputs, labels = Variable(inputs.cuda(), volatile=True), Variable(labels.cuda(), volatile=True)
        #else:
        #    inputs, labels = Variable(inputs, volatile=True), Variable(labels, volatile=True)

        outputs = vgg(inputs)

        _, preds = torch.max(outputs.data, 1)
        loss = criterion(outputs, labels)
        print(loss)
        #loss_test += loss.data[0]
        acc_test += torch.sum(preds == labels.data)
        print(acc_test)
        print(len(labels))

        del inputs, labels, outputs, preds
        torch.cuda.empty_cache()
        
    #avg_loss = loss_test / dataset_sizes[TEST]
    #avg_acc = acc_test / dataset_sizes[TEST]
    
    elapsed_time = time.time() - since
    print()
    print("Evaluation completed in {:.0f}m {:.0f}s".format(elapsed_time // 60, elapsed_time % 60))
    #print("Avg loss (test): {:.4f}".format(avg_loss))
    #print("Avg acc (test): {:.4f}".format(avg_acc))
    print('-' * 10)

# %%
#if use_gpu:

vgg16.cuda() #.cuda() will move everything to the GPU side
    
criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(vgg16.parameters(), lr=0.001, momentum=0.9)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
print("Test before training")
eval_model(vgg16, criterion)
# Out:
# Test before training
# Evaluating model
# ----------
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 0
# Test batch 0/144tensor(1.8794, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3, device='cuda:0')
# 10
# <ipython-input-43-3efadbe1a2f3>:23: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs, labels = Variable(inputs.cuda(), volatile=True), Variable(labels.cuda(), volatile=True)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 1
# tensor(2.3361, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 2
# tensor(2.4214, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 3
# tensor(3.0453, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(13, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 4
# tensor(2.5949, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(15, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(6., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 5
# tensor(2.6488, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(17, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 6
# tensor(2.2683, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(20, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 7
# tensor(2.5914, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(22, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 8
# tensor(2.0687, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(27, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 9
# tensor(2.4988, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(30, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 10
# tensor(2.0706, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(33, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(6., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 11
# tensor(2.7145, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(36, device='cuda:0')
# 10
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 12
# tensor(2.2517, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(39, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 13
# tensor(2.0971, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(42, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 14
# tensor(2.1885, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(45, device='cuda:0')
# 10
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 15
# tensor(3.2402, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(46, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 16
# tensor(2.6672, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(47, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(6., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 17
# tensor(1.9701, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(50, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 18
# tensor(3.1040, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(53, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 19
# tensor(1.6696, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(58, device='cuda:0')
# 10
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 20
# tensor(2.5961, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(59, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 21
# tensor(1.5603, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(65, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 22
# tensor(3.2752, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(66, device='cuda:0')
# 10
# tensor(6., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 23
# tensor(2.5772, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(69, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 24
# tensor(2.8100, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(71, device='cuda:0')
# 10
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 25
# tensor(2.8195, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(72, device='cuda:0')
# 10
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 26
# tensor(2.2545, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(76, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 27
# tensor(2.8369, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(79, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 28
# tensor(1.8546, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(84, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 29
# tensor(3.5340, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(85, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 30
# tensor(2.1957, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(87, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 31
# tensor(2.0509, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(91, device='cuda:0')
# 10
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 32
# tensor(1.9487, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(94, device='cuda:0')
# 10
# tensor(0., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 33
# tensor(2.8183, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(95, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 34
# tensor(2.3867, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(97, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 35
# tensor(2.1816, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(101, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 36
# tensor(2.1026, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(104, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 37
# tensor(2.0973, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(108, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 38
# tensor(2.1820, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(113, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 39
# tensor(2.2679, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(115, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 40
# tensor(1.5951, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(120, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 41
# tensor(1.5679, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(125, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 42
# tensor(1.5533, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(132, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 43
# tensor(3.2400, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(134, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 44
# tensor(2.4617, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(136, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 45
# tensor(3.0906, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(137, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 46
# tensor(1.8723, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(140, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 47
# tensor(2.9356, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(142, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 48
# tensor(1.9470, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(145, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 49
# tensor(2.6647, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(149, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 50
# tensor(2.6230, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(151, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(6., dtype=torch.float64)
# 51
# tensor(2.9276, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(152, device='cuda:0')
# 10
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 52
# tensor(1.2526, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(159, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 53
# tensor(2.9509, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(160, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 54
# tensor(1.9158, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(165, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 55
# tensor(2.3702, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(168, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 56
# tensor(2.7519, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(170, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 57
# tensor(3.0787, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(172, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 58
# tensor(2.7657, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(174, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(6., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 59
# tensor(2.0482, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(176, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 60
# tensor(1.7931, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(180, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 61
# tensor(2.5298, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(181, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 62
# tensor(2.7357, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(182, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 63
# tensor(2.5455, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(184, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 64
# tensor(2.8970, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(186, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 65
# tensor(1.7855, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(191, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 66
# tensor(2.2507, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(193, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 67
# tensor(1.9576, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(198, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 68
# tensor(3.1438, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(201, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 69
# tensor(1.8570, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(205, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 70
# tensor(2.2656, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(207, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 71
# tensor(1.9595, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(209, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 72
# tensor(2.9297, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(211, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 73
# tensor(2.5469, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(214, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 74
# tensor(1.7138, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(219, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 75
# tensor(1.9655, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(222, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 76
# tensor(2.1585, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(225, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 77
# tensor(2.0672, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(227, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 78
# tensor(3.1573, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(228, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 79
# tensor(2.0720, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(231, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 80
# tensor(2.5281, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(234, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 81
# tensor(2.1367, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(238, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 82
# tensor(2.2518, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(241, device='cuda:0')
# 10
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 83
# tensor(2.2892, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(245, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 84
# tensor(2.9164, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(247, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 85
# tensor(2.3738, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(251, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 86
# tensor(2.7764, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(252, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 87
# tensor(2.2334, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(255, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 88
# tensor(2.2647, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(259, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 89
# tensor(2.2132, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(261, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 90
# tensor(2.4031, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(264, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 91
# tensor(1.7189, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(270, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 92
# tensor(1.5498, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(275, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 93
# tensor(2.3436, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(277, device='cuda:0')
# 10
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(6., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 94
# tensor(2.2284, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(278, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 95
# tensor(2.9908, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(281, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 96
# tensor(1.9664, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(284, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 97
# tensor(1.8824, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(289, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 98
# tensor(1.9803, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(292, device='cuda:0')
# 10
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(6., dtype=torch.float64)
# 99
# tensor(1.5349, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(297, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 100
# Test batch 100/144tensor(2.2004, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(301, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 101
# tensor(2.5708, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(302, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 102
# tensor(2.0406, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(306, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 103
# tensor(1.8056, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(310, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 104
# tensor(1.8335, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(314, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 105
# tensor(1.5175, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(319, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 106
# tensor(2.4273, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(323, device='cuda:0')
# 10
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 107
# tensor(1.9435, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(326, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 108
# tensor(2.0016, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(331, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 109
# tensor(1.7476, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(336, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 110
# tensor(3.1310, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(337, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 111
# tensor(2.3996, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(340, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 112
# tensor(1.9920, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(343, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 113
# tensor(1.4016, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(349, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 114
# tensor(2.6720, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(352, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 115
# tensor(2.8082, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(354, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 116
# tensor(2.3946, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(357, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 117
# tensor(2.7705, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(361, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 118
# tensor(3.0065, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(364, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 119
# tensor(2.3136, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(367, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 120
# tensor(1.5782, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(372, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 121
# tensor(1.9543, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(376, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 122
# tensor(2.5230, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(380, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 123
# tensor(1.9000, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(384, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 124
# tensor(1.8252, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(389, device='cuda:0')
# 10
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 125
# tensor(1.5923, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(394, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 126
# tensor(2.3496, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(396, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 127
# tensor(3.7622, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(396, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 128
# tensor(1.7448, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(401, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 129
# tensor(3.5173, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(401, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(6., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 130
# tensor(2.7825, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(402, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 131
# tensor(1.4228, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(408, device='cuda:0')
# 10
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 132
# tensor(2.1156, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(413, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 133
# tensor(1.8187, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(419, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# 134
# tensor(2.7050, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(422, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 135
# tensor(1.9662, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(426, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 136
# tensor(2.6166, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(430, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 137
# tensor(2.7308, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(432, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 138
# tensor(1.8170, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(437, device='cuda:0')
# 10
# tensor(4., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(0., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# 139
# tensor(3.2885, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(438, device='cuda:0')
# 10
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(1., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# 140
# tensor(3.3502, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(439, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(5., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 141
# tensor(1.8868, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(442, device='cuda:0')
# 10
# tensor(1., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# tensor(4., dtype=torch.float64)
# tensor(2., dtype=torch.float64)
# 142
# tensor(1.9949, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(446, device='cuda:0')
# 10
# tensor(2., dtype=torch.float64)
# tensor(3., dtype=torch.float64)
# 143
# tensor(1.5419, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(447, device='cuda:0')
# 2
#
# Evaluation completed in 15m 10s
# ----------

# %%
def train_model(vgg, criterion, optimizer, scheduler, num_epochs=10):
    since = time.time()
    best_model_wts = copy.deepcopy(vgg.state_dict())
    best_acc = 0.0
    
    avg_loss = 0
    avg_acc = 0
    avg_loss_val = 0
    avg_acc_val = 0
    
    train_batches = len(train)
    val_batches = len(train)
    
    for epoch in range(num_epochs):
        print("Epoch {}/{}".format(epoch, num_epochs))
        print('-' * 10)
        
        loss_train = 0
        loss_val = 0
        acc_train = 0
        acc_val = 0
        
        vgg.train(True)
        count_of_train_data = 0
        for i, data in enumerate(train):
            count_of_train_data = count_of_train_data + len(train)
            if i % 100 == 0:
                print("\rTraining batch {}/{}".format(i, train_batches / 2), end='', flush=True)
                
            # Use half training dataset
            if i >= train_batches / 2:
                break
                
            inputs, labels = data
            labels = labels.type(torch.LongTensor)
            
            #if use_gpu:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
            #else:
            #    inputs, labels = Variable(inputs), Variable(labels)
            
            optimizer.zero_grad()
            
            outputs = vgg(inputs)
            
            _, preds = torch.max(outputs.data, 1)
            loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()
            #print(loss)
            #loss_train += loss.data[0]
            acc_train += torch.sum(preds == labels.data)
            
            del inputs, labels, outputs, preds
            torch.cuda.empty_cache()
            #break
        
        print()
        # * 2 as we only used half of the dataset
        avg_loss = loss_train / count_of_train_data
        avg_acc = acc_train / count_of_train_data
        
        vgg.train(False)
        vgg.eval()
            
        count_of_data = 0 
        for i, data in enumerate(val):
            count_of_data = count_of_data + len(val)
            if i % 100 == 0:
                print("\rValidation batch {}/{}".format(i, val_batches), end='', flush=True)
                
            inputs, labels = data
            labels = labels.type(torch.LongTensor)
            #if use_gpu:
            inputs, labels = Variable(inputs.cuda(), volatile=True), Variable(labels.cuda(), volatile=True)
            #else:
            #    inputs, labels = Variable(inputs, volatile=True), Variable(labels, volatile=True)
            
            optimizer.zero_grad()
            
            outputs = vgg(inputs)
            
            _, preds = torch.max(outputs.data, 1)
            loss = criterion(outputs, labels)
            
            #loss_val += loss.data[0]
            acc_val += torch.sum(preds == labels.data)
            
            del inputs, labels, outputs, preds
            torch.cuda.empty_cache()
            #break
            
        
        
        avg_loss_val = loss_val / count_of_data
        avg_acc_val = acc_val / count_of_data
        
        print()
        print("Epoch {} result: ".format(epoch))
        print("Avg loss (train): {:.4f}".format(avg_loss))
        print("Avg acc (train): {:.4f}".format(avg_acc))
        print("Avg loss (val): {:.4f}".format(avg_loss_val))
        print("Avg acc (val): {:.4f}".format(avg_acc_val))
        print('-' * 10)
        print()
        
        if avg_acc_val > best_acc:
            best_acc = avg_acc_val
            best_model_wts = copy.deepcopy(vgg.state_dict())
        
    elapsed_time = time.time() - since
    print()
    print("Training completed in {:.0f}m {:.0f}s".format(elapsed_time // 60, elapsed_time % 60))
    print("Best acc: {:.4f}".format(best_acc))
    
    vgg.load_state_dict(best_model_wts)
    return vgg

# %%
vgg16 = train_model(vgg16, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=30)
torch.save(vgg16.state_dict(), 'VGG16_v2-OCT_Retina_half_dataset.pt')
# Out:
# Epoch 0/30
# ----------
# Training batch 200/251.0
# Validation batch 0/502
# <ipython-input-14-3e252b45544f>:76: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs, labels = Variable(inputs.cuda(), volatile=True), Variable(labels.cuda(), volatile=True)
# Epoch 0 result:
# Avg loss (train): 0.0000
# Avg acc (train): 0.0067
# Avg loss (val): 0.0000
# Avg acc (val): 0.0540
# ----------
#
# Epoch 1/30
# ----------
# Training batch 100/251.0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-a45ceb1d32bd> in <cell line: 1>()
# ----> 1 vgg16 = train_model(vgg16, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=30)
#       2 torch.save(vgg16.state_dict(), 'VGG16_v2-OCT_Retina_half_dataset.pt')
#
# <ipython-input-14-3e252b45544f> in train_model(vgg, criterion, optimizer, scheduler, num_epochs)
#      23         vgg.train(True)
#      24         count_of_train_data = 0
# ---> 25         for i, data in enumerate(train):
#      26             count_of_train_data = count_of_train_data + len(train)
#      27             if i % 100 == 0:
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1331             else:
#    1332                 del self._task_info[idx]
# -> 1333                 return self._process_data(data)
#    1334
#    1335     def _try_put_index(self):
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1357         self._try_put_index()
#    1358         if isinstance(data, ExceptionWrapper):
# -> 1359             data.reraise()
#    1360         return data
#    1361
#
# /usr/local/lib/python3.9/dist-packages/torch/_utils.py in reraise(self)
#     541             # instantiate since we don't know how to
#     542             raise RuntimeError(msg) from None
# --> 543         raise exception
#     544
#     545
#
# FileNotFoundError: Caught FileNotFoundError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/worker.py", line 302, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/fetch.py", line 58, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/fetch.py", line 58, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataset.py", line 295, in __getitem__
#     return self.dataset[self.indices[idx]]
#   File "<ipython-input-7-35a85670079f>", line 43, in __getitem__
#     image = Image.open(img_path)
#   File "/usr/local/lib/python3.9/dist-packages/PIL/Image.py", line 2975, in open
#     fp = builtins.open(filename, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/processed_images/ciaa199.pdf-001-c.png'
